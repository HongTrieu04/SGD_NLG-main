# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/SGSA-main/SGD-NLG-master/
# Out:
# /content/drive/MyDrive/SGSA-main/SGD-NLG-master

# %%
cd /content/drive/MyDrive/SGD_NLG_master/
# Out:
# /content/drive/MyDrive/SGD_NLG_master

# %%
# Install libraries
# !pip install datasets==2.16.1
# !pip install lightning==1.9.3
# !pip install wandb
# !pip install pytorch-lightning

# %%
# cff9cbeb113b2e73794f16c24478d76d71b0a45a
# !wandb login
# Out:
# wandb: Currently logged in as: 22024562 (22024562-vietnam-national-university-hanoi). Use `wandb login --relogin` to force relogin

# %%
# !bash ectrain t5-small-SGD local
# Out:
# config=
# Training is configured as below:
# ---
# # Meta Info
#   ModelName: "t5-small-SGD"
#   ExpName: &exp_name "schema-guided"
#   VerName: &ver_name "adamw-train-1"
#   WandbProject: &wandb_project bbyrne-nlg
#   Note: "t5-small for SGD, using schema-guided linearization"
#
# # Tokenizer
#   TokenizerInfo:
#     tokenizer_class: T5TokenizerFast
#     tokenizer_name: &tk_name t5-small
#     tokenizer_alias: &tk_alias T5TokenizerFast
#
# # LightningModule
#   LightningModuleName: "HFGenerationModel"
#   LightningModuleParas:
#     model_path: "t5-small" # assuming root-dir under models/<model_name>
#     optimizer: AdamW
#     optimizer_params:
#       lr: 0.0001
#       # scale_parameter: false
#       # relative_step: false
#       # warmup_init: false
#
#
# # LightningDataModule
#   LightningDataModuleName: "GEMSGD_DataModule"
#   LightningDataModuleParas:
#     batch_size: 8
#     tokenizer_name: *tk_alias
#     force_process: false
#     save_cache: true
#     encode_args:
# ...
